# %% [markdown]
# ## References
# - https://github.com/GlacioHack/geoprofile
# - https://github.com/adehecq/ragmac_xdem/blob/master/ragmac_xdem/dem_postprocessing.py#L777
# - https://github.com/geohackweek/tutorial_contents/blob/master/vector/notebooks/geoviews_example.ipynb
# - https://geoviews.org/user_guide/Resampling_Grids.html
# - https://xdem.readthedocs.io/en/latest/terrain.html

# %% [markdown]
# ### Data download

# %%
import gdown

# %%
# url = "https://drive.google.com/file/d/1ueZKYQt-jnD05_qTd9h3_Wno6U9-M-_h/view?usp=sharing"
# output = 'scg_test_data.tar.gz'

# gdown.download(url=url, output=output, quiet=False, fuzzy=True)
# ! tar -xvzf scg_test_data.tar.gz
# ! rm scg_test_data.tar.gz
! tree
# Out:
# .
# ├── scg_test_data
# │   ├── dem_1967-09-21.tif
# │   ├── dem_1970-09-29.tif
# │   ├── dem_1974-08-10.tif
# │   ├── dem_1977-10-03.tif
# │   ├── dem_1979-08-20.tif
# │   ├── dem_1979-10-06.tif
# │   ├── dem_1984-08-14.tif
# │   ├── dem_1986-09-05.tif
# │   ├── dem_1987-08-21.tif
# │   ├── dem_1990-09-05.tif
# │   ├── dem_1991-09-09.tif
# │   ├── dem_1992-07-28.tif
# │   ├── dem_1992-09-15.tif
# │   ├── dem_1992-09-18.tif
# │   ├── dem_1992-10-06.tif
# │   ├── dem_1994-09-06.tif
# │   ├── dem_1996-09-10.tif
# │   ├── dem_1997-09-23.tif
# │   ├── dod_1967-09-21.tif
# │   ├── dod_1970-09-29.tif
# │   ├── dod_1974-08-10.tif
# │   ├── dod_1977-10-03.tif
# │   ├── dod_1979-08-20.tif
# │   ├── dod_1979-10-06.tif
# │   ├── dod_1984-08-14.tif
# │   ├── dod_1986-09-05.tif
# │   ├── dod_1987-08-21.tif
# │   ├── dod_1990-09-05.tif
# │   ├── dod_1991-09-09.tif
# │   ├── dod_1992-07-28.tif
# │   ├── dod_1992-09-15.tif
# │   ├── dod_1992-09-18.tif
# │   ├── dod_1992-10-06.tif
# ...

# %% [markdown]
# ### Wrangling
# - stack DEMs into xarray dataset and [make sure they are aligned](https://github.com/adehecq/ragmac_xdem/blob/master/ragmac_xdem/io.py#L163)
# - create [derivative products on the fly](https://xdem.readthedocs.io/en/latest/terrain.html)

# %%
# Out:
# Column
#     [0] Row
#         [0] HoloViews(DynamicMap)
#         [1] Column
#             [0] WidgetBox
#                 [0] DiscreteSlider(margin=(20, 20, 20, 20), name='Time', options=OrderedDict([('2013-01-01 ...]), value=numpy.datetime64('2013-01-..., width=250)
#             [1] VSpacer()
#     [1] HoloViews(DynamicMap)

# %% [markdown]
# ### Plotting
# - plot DEMs with hillshade
# - plot slope, aspect, curvature, roughness etc
# - make sure all panels are linked on zoom
# - create time series plot when selecting a point
#  - add [linear regression line](https://github.com/adehecq/ragmac_xdem/blob/master/notebooks/temporal_fitting_analysis.ipynb) for time series at selected point
#  - add Gaussian Process regression line for time series at selected point
# - plot a reference DEM
#  - plot coreg area after masking
#  - plot DoD [semivariogram](https://xdem.readthedocs.io/en/latest/spatialstats.html)
#  - plot DoD [robust stats](https://xdem.readthedocs.io/en/latest/robuststats.html) (histogram of difference values over stable surfaces after masking)
